# %% [markdown]
# # World Happiness Report

# %%
import pandas as pd

# %%
data1=pd.read_csv('Downloads/Happiness World Report 2015-2019/2015.csv')
data2=pd.read_csv('Downloads/Happiness World Report 2015-2019/2016.csv')
data3=pd.read_csv('Downloads/Happiness World Report 2015-2019/2017.csv')
data4=pd.read_csv('Downloads/Happiness World Report 2015-2019/2018.csv')
data5=pd.read_csv('Downloads/Happiness World Report 2015-2019/2019.csv')


df = pd.concat(map(pd.read_csv, ['Downloads/Happiness World Report 2015-2019/2015.csv', 
                                'Downloads/Happiness World Report 2015-2019/2016.csv',
                                 'Downloads/Happiness World Report 2015-2019/2017.csv',
                                 'Downloads/Happiness World Report 2015-2019/2018.csv',
                                 'Downloads/Happiness World Report 2015-2019/2019.csv']))
#df.info()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data1.shape
data2.shape
data3.shape
data4.shape
data5.shape
# Out:
# (156, 9)

# %%
pd.merge(data1, data2, how='outer')
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 310        Benin               Sub-Saharan Africa             153
# 311  Afghanistan                    Southern Asia             154
# 312         Togo               Sub-Saharan Africa             155
# 313        Syria  Middle East and Northern Africa             156
# 314      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...
